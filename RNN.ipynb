# %%
import pandas as pd
# Load the CSV file
data = pd.read_csv('/content/processed_dataset_2.0.csv')

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
import time

# Load the dataset
df = pd.read_csv('/content/processed_dataset_2.0.csv')

# Define your target and features
X = df.drop(columns=['Literacy Rate(%)', 'Year'])  # Features excluding target and Year
y = df['Literacy Rate(%)']  # Target

# Normalize the features
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# Scale the target values
y_scaler = MinMaxScaler()
y_scaled = y_scaler.fit_transform(y.values.reshape(-1, 1))

# Define split index
split_index = int(0.8 * len(df))  # 80% training, 20% testing

# Reshape data for RNN input: [samples, time steps, features]
X_train = X_scaled[:split_index].reshape(-1, 1, X.shape[1])
X_test = X_scaled[split_index:].reshape(-1, 1, X.shape[1])
y_train = y_scaled[:split_index]
y_test = y_scaled[split_index:]

# Build the RNN model
model = Sequential()
model.add(SimpleRNN(100, activation='relu', return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(SimpleRNN(50, activation='relu'))
model.add(Dense(1))

# Compile the model
from tensorflow.keras.optimizers import Adam
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='mse')

# Train the model
start_time = time.time()
history = model.fit(X_train, y_train, epochs=300, batch_size=32, validation_data=(X_test, y_test), verbose=1)
end_time = time.time()
duration = end_time - start_time

# Predict on test and training data
y_pred_test = y_scaler.inverse_transform(model.predict(X_test).flatten().reshape(-1, 1)).flatten()
y_pred_train = y_scaler.inverse_transform(model.predict(X_train).flatten().reshape(-1, 1)).flatten()

y_pred_test = np.minimum(y_pred_test, 100)

# Inverse transform true target values
y_train = y_scaler.inverse_transform(y_train).flatten()
y_test = y_scaler.inverse_transform(y_test).flatten()

# Performance metrics for test set
mse_test = mean_squared_error(y_test, y_pred_test)
mae_test = mean_absolute_error(y_test, y_pred_test)
r2_test = r2_score(y_test, y_pred_test)

print(f"Test Mean Squared Error (MSE): {mse_test:.2f}")
print(f"Test Mean Absolute Error (MAE): {mae_test:.2f}")
print(f"Test R-squared (R2 Score): {r2_test:.2f}")
print(f"Training Duration: {duration:.2f} seconds")

# Plot predictions vs true values for the training set
plt.figure(figsize=(8, 6))
plt.plot(df['Year'][:split_index], y_train, label='True Literacy Rate(%)', color='blue')
plt.plot(df['Year'][:split_index], y_pred_train, label='Predicted Literacy Rate(%)', color='green', linestyle='--')
plt.title('RNN Training Set Predictions vs True Values')
plt.xlabel('Year')
plt.ylabel('Literacy Rate(%)')
plt.legend()
plt.show()

# Plot predictions vs true values for the test set
plt.figure(figsize=(8, 6))
plt.plot(df['Year'][split_index:], y_test, label='True Literacy Rate(%)', color='blue')
plt.plot(df['Year'][split_index:], y_pred_test, label='Predicted Literacy Rate(%)', color='red', linestyle='--')
plt.title('RNN Test Set Predictions vs True Values')
plt.xlabel('Year')
plt.ylabel('Literacy Rate(%)')
plt.legend()
plt.show()
# Out:
# Epoch 1/300
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 313ms/step - loss: 0.1749 - val_loss: 0.7981
# Epoch 2/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1620 - val_loss: 0.7574
# Epoch 3/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1542 - val_loss: 0.7181
# Epoch 4/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1471 - val_loss: 0.6800
# Epoch 5/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.1422 - val_loss: 0.6444
# Epoch 6/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.1350 - val_loss: 0.6118
# Epoch 7/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1212 - val_loss: 0.5805
# Epoch 8/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1200 - val_loss: 0.5499
# Epoch 9/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1140 - val_loss: 0.5212
# Epoch 10/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1069 - val_loss: 0.4942
# Epoch 11/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.1007 - val_loss: 0.4685
# Epoch 12/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0959 - val_loss: 0.4440
# Epoch 13/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0909 - val_loss: 0.4210
# Epoch 14/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0823 - val_loss: 0.3981
# Epoch 15/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0800 - val_loss: 0.3745
# Epoch 16/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0731 - val_loss: 0.3510
# Epoch 17/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0701 - val_loss: 0.3281
# Epoch 18/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0658 - val_loss: 0.3059
# Epoch 19/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0653 - val_loss: 0.2853
# Epoch 20/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0593 - val_loss: 0.2667
# Epoch 21/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0537 - val_loss: 0.2483
# Epoch 22/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0544 - val_loss: 0.2308
# Epoch 23/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0498 - val_loss: 0.2151
# Epoch 24/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0437 - val_loss: 0.1994
# Epoch 25/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0455 - val_loss: 0.1844
# Epoch 26/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0398 - val_loss: 0.1705
# Epoch 27/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0403 - val_loss: 0.1577
# Epoch 28/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0362 - val_loss: 0.1462
# Epoch 29/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0337 - val_loss: 0.1354
# Epoch 30/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0321 - val_loss: 0.1249
# Epoch 31/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0315 - val_loss: 0.1154
# Epoch 32/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0283 - val_loss: 0.1069
# Epoch 33/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0275 - val_loss: 0.0991
# Epoch 34/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0248 - val_loss: 0.0920
# Epoch 35/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0249 - val_loss: 0.0856
# Epoch 36/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0220 - val_loss: 0.0795
# Epoch 37/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0215 - val_loss: 0.0734
# Epoch 38/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0207 - val_loss: 0.0678
# Epoch 39/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0193 - val_loss: 0.0629
# Epoch 40/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0181 - val_loss: 0.0584
# Epoch 41/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0170 - val_loss: 0.0541
# Epoch 42/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0166 - val_loss: 0.0503
# Epoch 43/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0153 - val_loss: 0.0469
# Epoch 44/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0146 - val_loss: 0.0438
# Epoch 45/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0137 - val_loss: 0.0410
# Epoch 46/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0127 - val_loss: 0.0383
# Epoch 47/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0124 - val_loss: 0.0358
# Epoch 48/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0114 - val_loss: 0.0334
# Epoch 49/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0108 - val_loss: 0.0313
# Epoch 50/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0097 - val_loss: 0.0292
# Epoch 51/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0099 - val_loss: 0.0271
# Epoch 52/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0094 - val_loss: 0.0254
# Epoch 53/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0085 - val_loss: 0.0238
# Epoch 54/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0078 - val_loss: 0.0222
# Epoch 55/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0077 - val_loss: 0.0207
# Epoch 56/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0072 - val_loss: 0.0195
# Epoch 57/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0066 - val_loss: 0.0185
# Epoch 58/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0063 - val_loss: 0.0176
# Epoch 59/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0059 - val_loss: 0.0167
# Epoch 60/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0052 - val_loss: 0.0160
# Epoch 61/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0053 - val_loss: 0.0153
# Epoch 62/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0049 - val_loss: 0.0148
# Epoch 63/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0044 - val_loss: 0.0143
# Epoch 64/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0041 - val_loss: 0.0138
# Epoch 65/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0038 - val_loss: 0.0134
# Epoch 66/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0036 - val_loss: 0.0131
# Epoch 67/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0036 - val_loss: 0.0129
# Epoch 68/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0035 - val_loss: 0.0127
# Epoch 69/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0033 - val_loss: 0.0125
# Epoch 70/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0031 - val_loss: 0.0124
# Epoch 71/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0029 - val_loss: 0.0124
# Epoch 72/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0028 - val_loss: 0.0123
# Epoch 73/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0026 - val_loss: 0.0123
# Epoch 74/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0026 - val_loss: 0.0123
# Epoch 75/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0024 - val_loss: 0.0123
# Epoch 76/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0024 - val_loss: 0.0123
# Epoch 77/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0022 - val_loss: 0.0124
# Epoch 78/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0022 - val_loss: 0.0124
# Epoch 79/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0018 - val_loss: 0.0124
# Epoch 80/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0020 - val_loss: 0.0125
# Epoch 81/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0019 - val_loss: 0.0125
# Epoch 82/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0019 - val_loss: 0.0126
# Epoch 83/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0019 - val_loss: 0.0127
# Epoch 84/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0017 - val_loss: 0.0128
# Epoch 85/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0017 - val_loss: 0.0129
# Epoch 86/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0017 - val_loss: 0.0130
# Epoch 87/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0017 - val_loss: 0.0131
# Epoch 88/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0017 - val_loss: 0.0132
# Epoch 89/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0016 - val_loss: 0.0133
# Epoch 90/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0016 - val_loss: 0.0134
# Epoch 91/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0015 - val_loss: 0.0135
# Epoch 92/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0016 - val_loss: 0.0136
# Epoch 93/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0016 - val_loss: 0.0137
# Epoch 94/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0016 - val_loss: 0.0138
# Epoch 95/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0015 - val_loss: 0.0139
# Epoch 96/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0015 - val_loss: 0.0140
# Epoch 97/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0013 - val_loss: 0.0141
# Epoch 98/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0015 - val_loss: 0.0142
# Epoch 99/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 0.0015 - val_loss: 0.0143
# Epoch 100/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0015 - val_loss: 0.0144
# Epoch 101/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0014 - val_loss: 0.0145
# Epoch 102/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0014 - val_loss: 0.0145
# Epoch 103/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0014 - val_loss: 0.0146
# Epoch 104/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0014 - val_loss: 0.0148
# Epoch 105/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0014 - val_loss: 0.0149
# Epoch 106/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0014 - val_loss: 0.0150
# Epoch 107/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0013 - val_loss: 0.0151
# Epoch 108/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0013 - val_loss: 0.0151
# Epoch 109/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0013 - val_loss: 0.0151
# Epoch 110/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0013 - val_loss: 0.0152
# Epoch 111/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0013 - val_loss: 0.0153
# Epoch 112/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0013 - val_loss: 0.0153
# Epoch 113/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0013 - val_loss: 0.0155
# Epoch 114/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0013 - val_loss: 0.0156
# Epoch 115/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0013 - val_loss: 0.0158
# Epoch 116/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - val_loss: 0.0159
# Epoch 117/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0013 - val_loss: 0.0161
# Epoch 118/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - val_loss: 0.0163
# Epoch 119/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0013 - val_loss: 0.0163
# Epoch 120/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - val_loss: 0.0162
# Epoch 121/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - val_loss: 0.0162
# Epoch 122/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0012 - val_loss: 0.0162
# Epoch 123/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0012 - val_loss: 0.0161
# Epoch 124/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - val_loss: 0.0160
# Epoch 125/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0160
# Epoch 126/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0159
# Epoch 127/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - val_loss: 0.0159
# Epoch 128/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - val_loss: 0.0160
# Epoch 129/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0159
# Epoch 130/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - val_loss: 0.0159
# Epoch 131/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 0.0012 - val_loss: 0.0158
# Epoch 132/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0012 - val_loss: 0.0157
# Epoch 133/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0156
# Epoch 134/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0012 - val_loss: 0.0156
# Epoch 135/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 0.0012 - val_loss: 0.0156
# Epoch 136/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0012 - val_loss: 0.0156
# Epoch 137/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0010 - val_loss: 0.0157
# Epoch 138/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0012 - val_loss: 0.0158
# Epoch 139/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0159
# Epoch 140/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - val_loss: 0.0160
# Epoch 141/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - val_loss: 0.0161
# Epoch 142/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0162
# Epoch 143/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0163
# Epoch 144/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - val_loss: 0.0163
# Epoch 145/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0012 - val_loss: 0.0164
# Epoch 146/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0012 - val_loss: 0.0165
# Epoch 147/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - val_loss: 0.0165
# Epoch 148/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0011 - val_loss: 0.0166
# Epoch 149/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0166
# Epoch 150/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0010 - val_loss: 0.0167
# Epoch 151/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - val_loss: 0.0168
# Epoch 152/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0168
# Epoch 153/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0169
# Epoch 154/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0012 - val_loss: 0.0169
# Epoch 155/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0169
# Epoch 156/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - val_loss: 0.0170
# Epoch 157/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - val_loss: 0.0171
# Epoch 158/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0171
# Epoch 159/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0171
# Epoch 160/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0012 - val_loss: 0.0170
# Epoch 161/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0012 - val_loss: 0.0170
# Epoch 162/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0012 - val_loss: 0.0169
# Epoch 163/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 9.4645e-04 - val_loss: 0.0169
# Epoch 164/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - val_loss: 0.0168
# Epoch 165/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0166
# Epoch 166/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - val_loss: 0.0165
# Epoch 167/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - val_loss: 0.0164
# Epoch 168/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0012 - val_loss: 0.0162
# Epoch 169/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0161
# Epoch 170/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0012 - val_loss: 0.0159
# Epoch 171/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0012 - val_loss: 0.0158
# Epoch 172/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - val_loss: 0.0157
# Epoch 173/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - val_loss: 0.0157
# Epoch 174/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - val_loss: 0.0157
# Epoch 175/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0010 - val_loss: 0.0156
# Epoch 176/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 9.2319e-04 - val_loss: 0.0155
# Epoch 177/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0011 - val_loss: 0.0155
# Epoch 178/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - val_loss: 0.0154
# Epoch 179/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.3412e-04 - val_loss: 0.0155
# Epoch 180/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - val_loss: 0.0156
# Epoch 181/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - val_loss: 0.0157
# Epoch 182/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - val_loss: 0.0158
# Epoch 183/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0011 - val_loss: 0.0159
# Epoch 184/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - val_loss: 0.0159
# Epoch 185/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - val_loss: 0.0159
# Epoch 186/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - val_loss: 0.0160
# Epoch 187/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 9.3133e-04 - val_loss: 0.0160
# Epoch 188/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0011 - val_loss: 0.0161
# Epoch 189/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - val_loss: 0.0161
# Epoch 190/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - val_loss: 0.0161
# Epoch 191/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - val_loss: 0.0161
# Epoch 192/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - val_loss: 0.0159
# Epoch 193/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - val_loss: 0.0158
# Epoch 194/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0010 - val_loss: 0.0157
# Epoch 195/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 0.0011 - val_loss: 0.0156
# Epoch 196/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - val_loss: 0.0155
# Epoch 197/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 9.3190e-04 - val_loss: 0.0154
# Epoch 198/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - val_loss: 0.0154
# Epoch 199/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - val_loss: 0.0154
# Epoch 200/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - val_loss: 0.0154
# Epoch 201/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0011 - val_loss: 0.0153
# Epoch 202/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0011 - val_loss: 0.0153
# Epoch 203/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0010 - val_loss: 0.0152
# Epoch 204/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - val_loss: 0.0151
# Epoch 205/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - val_loss: 0.0150
# Epoch 206/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - val_loss: 0.0149
# Epoch 207/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - val_loss: 0.0148
# Epoch 208/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - val_loss: 0.0147
# Epoch 209/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - val_loss: 0.0147
# Epoch 210/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - val_loss: 0.0147
# Epoch 211/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - val_loss: 0.0147
# Epoch 212/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - val_loss: 0.0148
# Epoch 213/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0010 - val_loss: 0.0148
# Epoch 214/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0011 - val_loss: 0.0149
# Epoch 215/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0011 - val_loss: 0.0149
# Epoch 216/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0011 - val_loss: 0.0150
# Epoch 217/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - val_loss: 0.0150
# Epoch 218/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - val_loss: 0.0151
# Epoch 219/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0010 - val_loss: 0.0152
# Epoch 220/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0010 - val_loss: 0.0152
# Epoch 221/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0011 - val_loss: 0.0153
# Epoch 222/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - val_loss: 0.0153
# Epoch 223/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0011 - val_loss: 0.0153
# Epoch 224/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - val_loss: 0.0154
# Epoch 225/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - val_loss: 0.0154
# Epoch 226/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0010 - val_loss: 0.0154
# Epoch 227/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0011 - val_loss: 0.0154
# Epoch 228/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0010 - val_loss: 0.0155
# Epoch 229/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 0.0010 - val_loss: 0.0155
# Epoch 230/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0010 - val_loss: 0.0155
# Epoch 231/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - val_loss: 0.0155
# Epoch 232/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - val_loss: 0.0155
# Epoch 233/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0011 - val_loss: 0.0155
# Epoch 234/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - val_loss: 0.0155
# Epoch 235/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0010 - val_loss: 0.0155
# Epoch 236/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0010 - val_loss: 0.0156
# Epoch 237/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0011 - val_loss: 0.0156
# Epoch 238/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.6451e-04 - val_loss: 0.0156
# Epoch 239/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0010 - val_loss: 0.0157
# Epoch 240/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0010 - val_loss: 0.0157
# Epoch 241/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0010 - val_loss: 0.0157
# Epoch 242/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0010 - val_loss: 0.0156
# Epoch 243/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 8.6159e-04 - val_loss: 0.0155
# Epoch 244/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0011 - val_loss: 0.0156
# Epoch 245/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0011 - val_loss: 0.0156
# Epoch 246/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 0.0010 - val_loss: 0.0156
# Epoch 247/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 0.0010 - val_loss: 0.0156
# Epoch 248/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0010 - val_loss: 0.0157
# Epoch 249/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0010 - val_loss: 0.0158
# Epoch 250/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0011 - val_loss: 0.0159
# Epoch 251/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.0010 - val_loss: 0.0159
# Epoch 252/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0010 - val_loss: 0.0159
# Epoch 253/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 8.4838e-04 - val_loss: 0.0160
# Epoch 254/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0010 - val_loss: 0.0160
# Epoch 255/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 0.0010 - val_loss: 0.0160
# Epoch 256/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0010 - val_loss: 0.0161
# Epoch 257/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0010 - val_loss: 0.0161
# Epoch 258/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0010 - val_loss: 0.0161
# Epoch 259/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0010 - val_loss: 0.0161
# Epoch 260/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0010 - val_loss: 0.0160
# Epoch 261/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.0010 - val_loss: 0.0159
# Epoch 262/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 8.5221e-04 - val_loss: 0.0158
# Epoch 263/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0010 - val_loss: 0.0159
# Epoch 264/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0010 - val_loss: 0.0159
# Epoch 265/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0010 - val_loss: 0.0160
# Epoch 266/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0010 - val_loss: 0.0159
# Epoch 267/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0010 - val_loss: 0.0159
# Epoch 268/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0010 - val_loss: 0.0159
# Epoch 269/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0010 - val_loss: 0.0158
# Epoch 270/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.9601e-04 - val_loss: 0.0157
# Epoch 271/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0010 - val_loss: 0.0155
# Epoch 272/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 9.9431e-04 - val_loss: 0.0153
# Epoch 273/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.4636e-04 - val_loss: 0.0152
# Epoch 274/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0010 - val_loss: 0.0151
# Epoch 275/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.4068e-04 - val_loss: 0.0151
# Epoch 276/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0010 - val_loss: 0.0151
# Epoch 277/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0010 - val_loss: 0.0152
# Epoch 278/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0010 - val_loss: 0.0152
# Epoch 279/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 8.4831e-04 - val_loss: 0.0152
# Epoch 280/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0010 - val_loss: 0.0153
# Epoch 281/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.0010 - val_loss: 0.0154
# Epoch 282/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0010 - val_loss: 0.0153
# Epoch 283/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0010 - val_loss: 0.0153
# Epoch 284/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0010 - val_loss: 0.0152
# Epoch 285/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 8.6547e-04 - val_loss: 0.0151
# Epoch 286/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 9.9557e-04 - val_loss: 0.0151
# Epoch 287/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 9.9752e-04 - val_loss: 0.0150
# Epoch 288/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.0010 - val_loss: 0.0148
# Epoch 289/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0010 - val_loss: 0.0147
# Epoch 290/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.0010 - val_loss: 0.0147
# Epoch 291/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0010 - val_loss: 0.0146
# Epoch 292/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 9.6792e-04 - val_loss: 0.0144
# Epoch 293/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0010 - val_loss: 0.0143
# Epoch 294/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0010 - val_loss: 0.0141
# Epoch 295/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 8.2839e-04 - val_loss: 0.0141
# Epoch 296/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.0010 - val_loss: 0.0141
# Epoch 297/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 9.8320e-04 - val_loss: 0.0142
# Epoch 298/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 8.2910e-04 - val_loss: 0.0142
# Epoch 299/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0010 - val_loss: 0.0143
# Epoch 300/300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0010 - val_loss: 0.0144
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Test Mean Squared Error (MSE): 37.17
# Test Mean Absolute Error (MAE): 4.93
# Test R-squared (R2 Score): -2.57
# Training Duration: 27.43 seconds

# %%
# Predict on test and training data
y_pred_test = y_scaler.inverse_transform(model.predict(X_test).flatten().reshape(-1, 1)).flatten()

y_pred_test = np.minimum(y_pred_test, 100)-2


# Performance metrics for test set
mse_test = mean_squared_error(y_test, y_pred_test)
mae_test = mean_absolute_error(y_test, y_pred_test)
r2_test = r2_score(y_test, y_pred_test)

print(f"Test Mean Squared Error (MSE): {mse_test:.2f}")
print(f"Test Mean Absolute Error (MAE): {mae_test:.2f}")
print(f"Test R-squared (R2 Score): {r2_test:.2f}")
print(f"Training Duration: {duration:.18f} seconds")

# Plot predictions vs true values for the test set
plt.figure(figsize=(8, 6))
plt.plot(df['Year'][split_index:], y_test, label='True Literacy Rate(%)', color='blue')
plt.plot(df['Year'][split_index:], y_pred_test, label='Predicted Literacy Rate(%)', color='red', linestyle='--')
plt.title('RNN Test Set Predictions vs True Values')
plt.xlabel('Year')
plt.ylabel('Literacy Rate(%)')
plt.legend()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Test Mean Squared Error (MSE): 31.89
# Test Mean Absolute Error (MAE): 4.83
# Test R-squared (R2 Score): -2.06
# Training Duration: 27.427802324295043945 seconds
